# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np

# %%
cd /content/drive/MyDrive/Colab Notebooks/Github/where-is-my-home-ai
# Out:
# /content/drive/MyDrive/Colab Notebooks/Github/where-is-my-home-ai

# %%
pd.read_csv('data/아파트(매매)_실거래가_20240505175840.csv', encoding="CP949")
# Out:
#         NO            시군구   번지   본번  부번         단지명  전용면적(㎡)    계약년월  계약일  \
# 0        1  서울특별시 성동구 옥수동  561  561   0  래미안 옥수 리버젠   84.810  201502    1
# 1        2  서울특별시 성동구 옥수동  561  561   0  래미안 옥수 리버젠   84.810  201502    2
# 2        3  서울특별시 성동구 옥수동   60   60   0       풍림아이원   84.767  201502    2
# 3        4  서울특별시 성동구 옥수동  250  250   0        옥수삼성   84.822  201502    2
# 4        5  서울특별시 성동구 옥수동  100  100   0       옥수하이츠  114.720  201502    2
# ...    ...            ...  ...  ...  ..         ...      ...     ...  ...
# 9807  9808  서울특별시 강동구 강일동  699  699   0   강일리버파크9단지   84.530  201502   26
# 9808  9809  서울특별시 강동구 강일동  686  686   0   강일리버파크7단지   84.530  201502   26
# 9809  9810  서울특별시 강동구 강일동  670  670   0   강일리버파크5단지   84.830  201502   26
# 9810  9811  서울특별시 강동구 강일동  674  674   0   강일리버파크3단지   59.700  201502   27
# 9811  9812  서울특별시 강동구 강일동  670  670   0   강일리버파크5단지   84.830  201502   27
#
#      거래금액(만원)  동   층 매수자 매도자  건축년도         도로명 해제사유발생일 거래유형 중개사소재지 등기일자
# ...

# %%
data_set = pd.DataFrame()

pd.concat([data_set, pd.read_csv('data/아파트(매매)_실거래가_20240505175823.csv', encoding="CP949")])
# Out:
#         NO            시군구   번지   본번  부번         단지명  전용면적(㎡)    계약년월  계약일  \
# 0        1  서울특별시 성동구 옥수동  561  561   0  래미안 옥수 리버젠    84.81  201501    2
# 1        2  서울특별시 성동구 옥수동  561  561   0  래미안 옥수 리버젠    59.25  201501    3
# 2        3  서울특별시 성동구 옥수동  436  436   0        극동그린   114.32  201501    3
# 3        4  서울특별시 성동구 옥수동  561  561   0  래미안 옥수 리버젠    59.25  201501    6
# 4        5  서울특별시 성동구 옥수동  561  561   0  래미안 옥수 리버젠    59.25  201501    6
# ...    ...            ...  ...  ...  ..         ...      ...     ...  ...
# 9574  9575  서울특별시 강동구 강일동  701  701   0   강일리버파크8단지    84.83  201501   28
# 9575  9576  서울특별시 강동구 강일동  668  668   0   강일리버파크2단지    84.74  201501   29
# 9576  9577  서울특별시 강동구 강일동  699  699   0   강일리버파크9단지    84.53  201501   29
# 9577  9578  서울특별시 강동구 강일동  674  674   0   강일리버파크3단지    84.53  201501   31
# 9578  9579  서울특별시 강동구 강일동  717  717   0   고덕리엔파크2단지    59.72  201501   31
#
#      거래금액(만원)  동   층 매수자 매도자  건축년도         도로명 해제사유발생일 거래유형 중개사소재지 등기일자
# ...

# %%
for dirname, _, filenames in os.walk('data/'):
    for filename in filenames:
      print(os.path.join(dirname, filename))
# Out:
# data/아파트(매매)_실거래가_20240505171216.csv
# data/아파트(매매)_실거래가_20240505175823.csv
# data/아파트(매매)_실거래가_20240505175840.csv
# data/아파트(매매)_실거래가_20240505175853.csv
# data/아파트(매매)_실거래가_20240505182551.csv
# data/아파트(매매)_실거래가_20240505182605.csv
# data/아파트(매매)_실거래가_20240505180509.csv
# data/아파트(매매)_실거래가_20240505182624.csv
# data/아파트(매매)_실거래가_20240505182527.csv
# data/아파트(매매)_실거래가_20240505182558.csv
# data/아파트(매매)_실거래가_20240505180632.csv
# data/아파트(매매)_실거래가_20240505182459.csv
# data/아파트(매매)_실거래가_20240505175908.csv
# data/아파트(매매)_실거래가_20240505182449.csv
# data/아파트(매매)_실거래가_20240505182442.csv
# data/아파트(매매)_실거래가_20240505182515.csv
# data/아파트(매매)_실거래가_20240505182506.csv
# data/아파트(매매)_실거래가_20240505181513.csv
# data/아파트(매매)_실거래가_20240505182433.csv
# data/아파트(매매)_실거래가_20240505175900.csv
# ...

# %%
data_set = pd.DataFrame()

for dirname, _, filenames in os.walk('data/'):
    for filename in filenames:
      data_set = pd.concat([data_set, pd.read_csv(os.path.join(dirname, filename), encoding="CP949")])
# Out:
# <ipython-input-32-16f8b54895de>:5: DtypeWarning: Columns (0,9,11,12,13,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_set = pd.concat([data_set, pd.read_csv(os.path.join(dirname, filename), encoding="CP949")])

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 688557 entries, 0 to 11167
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   NO           688557 non-null  object
#  1   시군구          688557 non-null  object
#  2   번지           688557 non-null  object
#  3   본번           688557 non-null  int64
#  4   부번           688557 non-null  int64
#  5   단지명          688557 non-null  object
#  6   전용면적(㎡)      688557 non-null  object
#  7   계약년월         688557 non-null  float64
#  8   계약일          688557 non-null  int64
#  9   거래금액(만원)     688557 non-null  object
#  10  동            688557 non-null  object
#  11  층            688557 non-null  object
#  12  매수자          688557 non-null  object
#  13  매도자          688556 non-null  object
#  14  건축년도         688556 non-null  object
#  15  도로명          688557 non-null  object
#  16  해제사유발생일      688556 non-null  object
#  17  거래유형         688556 non-null  object
# ...

# %%
data_set = data_set.drop(['Unnamed: 20'], axis=1)

# %%
data_set = data_set.drop(['해제사유발생일', '거래유형', '중개사소재지', '등기일자', '매수자', '매도자'], axis=1)

# %%
data_set = data_set.drop(['NO'], axis=1)

# %%
data_set
# Out:
#                  시군구   번지   본번  부번         단지명 전용면적(㎡)      계약년월  계약일  \
# 0      서울특별시 성동구 옥수동  561  561   0  래미안 옥수 리버젠   84.81  201501.0    2
# 1      서울특별시 성동구 옥수동  561  561   0  래미안 옥수 리버젠   59.25  201501.0    3
# 2      서울특별시 성동구 옥수동  436  436   0        극동그린  114.32  201501.0    3
# 3      서울특별시 성동구 옥수동  561  561   0  래미안 옥수 리버젠   59.25  201501.0    6
# 4      서울특별시 성동구 옥수동  561  561   0  래미안 옥수 리버젠   59.25  201501.0    6
# ...              ...  ...  ...  ..         ...     ...       ...  ...
# 11163  서울특별시 강동구 강일동  674  674   0   강일리버파크3단지   84.83  202007.0    5
# 11164  서울특별시 강동구 강일동  717  717   0   고덕리엔파크2단지   84.87  202007.0    4
# 11165  서울특별시 강동구 강일동  665  665   0   강일리버파크1단지   59.87  202007.0    2
# 11166  서울특별시 강동구 강일동  699  699   0   강일리버파크9단지   84.53  202007.0    1
# 11167  서울특별시 강동구 강일동  665  665   0   강일리버파크1단지   84.53  202007.0    1
#
#       거래금액(만원)  동   층  건축년도          도로명
# 0       73,000  -  12  2012       매봉길 15
# 1       59,500  -  12  2012       매봉길 15
# ...

# %%
data_set = data_set[(data_set['시군구'].str.slice(start=0, stop=5) == '서울특별시')]

# %%
data_set['부번'].unique()
# Out:
# array([   0,    1,    2,    5,   76,   21,    3,   19,   15,   30,  922,
#         126,   95,   52,    4,   90,   51,   16,   45,  127,  158,    6,
#           8,   39,   31,   29,  389,  500,   28,   27,   23,  160,   10,
#          11,   63,  301,  170,  349,   60,  446,   17,  234,  320,  696,
#         157,    9,    7,   18,  103,   41,   20,   12,   66,  114,   25,
#          68,   40,   84,   33,   22,  168,  510,   56,  214,  490,   61,
#          74,   50,   13,   14,   24,   26,   48,   35,   89,  117,  106,
#         200,   36,   87,  105,  244,  108,   72,   34,   32,   46,   54,
#         212,  248,  123,  222,  223,  124,   73,  147,   59,   37,   70,
#          55,  332,   80,   82,   42,  215,  206,  264,  225,   69,   62,
#         622,   43,  283,  146,   53,  121,   88,   67,   38,   44,  132,
#         109,  252,  970, 1970,   64,  297,  421,   77,   65,  957,  183,
#         318,   93,   86,   81,   98,  112,   78,  275,  350,  511,   49,
# ...

# %%
data_set.to_csv('data/data_set.csv')

# %%
sido = []
gugun = []
dong = []

for dong_list in list(data_set['시군구'].str.split()):
  sido.append(dong_list[0])
  gugun.append(dong_list[1])
  dong.append(dong_list[2])

# %%
len(sido)
# Out:
# 628205

# %%
len(gugun)
# Out:
# 628205

# %%
len(dong)
# Out:
# 628205

# %%
data_set['sido'] = sido
data_set['gugun'] = gugun
data_set['dong'] = dong
# Out:
# <ipython-input-67-b5b239d173e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_set['sido'] = sido
# <ipython-input-67-b5b239d173e3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_set['gugun'] = gugun
# <ipython-input-67-b5b239d173e3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_set = data_set.drop(['시군구'], axis=1)

# %%
data_set.to_csv('data/data_set_div_sigugun.csv')

# %%
data_set['건축년도'].unique()
# Out:
# array([2012, 1997, 1986, 2004, 1999, 1982, 1990, 2003, 2008, 1981, 1994,
#        2006, 1996, 1992, 1993, 2002, 2013, 2009, 1971, 2001, 2000, 1975,
#        2011, 2010, 1968, 2005, 2014, 2007, 1977, 1978, 1998, 1973, 1995,
#        1970, 1974, 1979, 1976, 1984, 1989, 1983, 1985, 1987, 1991, 1988,
#        2015, 1972, 1980, 1969, 1966, 1967, 2016, 2017, 2018, 2019, 1965,
#        2020, 1961, 2022, 2021, 2023, '1998', '1997', '2012', '2003',
#        '1990', '2011', '1986', '1975', '1999', '2004', '1982', '2008',
#        '1983', '2006', '2015', '1995', '1993', '1992', '2002', '1968',
#        '1973', '1966', '2009', '2013', '2014', '1971', '2001', '2000',
#        '2010', '1976', '1981', '2005', '1994', '2016', '1980', '1974',
#        '1969', '1977', '2007', '1978', '1996', '1970', '1984', '1985',
#        '1989', '1987', '1988', '1991', '1972', '1979'], dtype=object)
